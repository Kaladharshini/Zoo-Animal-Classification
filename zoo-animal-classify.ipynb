# %%
# Importing the libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Importing the dataset
dataset1 = pd.read_csv('zoo.csv')
dataset1.shape
# Out:
# (101, 18)

# %%
dataset1.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    class_type
# 0           1
# 1           1
# 2           4
# ...

# %%
dataset2 = pd.read_csv('zoo2.csv')
dataset2.shape
# Out:
# (43, 18)

# %%
dataset2.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      turtle     0         0     1     0         0        1         0
# 1   chameleon     0         0     1     0         0        0         0
# 2      iguana     0         0     1     0         0        0         1
# 3      lizard     0         0     1     0         0        0         1
# 4       gecko     0         0     1     0         0        0         0
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        0         1         1         0     0     4     1         1        1
# 1        1         1         1         0     0     4     1         1        0
# 2        1         1         1         0     0     4     1         1        1
# 3        1         1         1         0     0     4     1         0        0
# 4        1         1         1         0     0     4     1         1        0
#
#    class_type
# 0           3
# 1           3
# 2           3
# ...

# %%
dataset3 = pd.read_csv('zoo3.csv')
dataset3.shape
# Out:
# (70, 18)

# %%
dataset3.head()
# Out:
#         animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0              anta     1         0     0     1         0        0         0
# 1          ariranha     1         0     0     1         0        1         1
# 2  boto-cor-de-rosa     0         0     0     1         0        1         1
# 3             bugio     1         0     0     1         0        0         0
# 4  cachorro-vinagre     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        0
# 1        1         1         1         0     1     4     1         0        0
# 2        1         1         1         0     1     0     1         0        0
# 3        1         1         1         0     0     4     1         0        0
# 4        1         1         1         0     0     4     1         0        1
#
#    class_type
# 0           1
# ...

# %%
dataset1['zoo_id'] = 'zoo1'
dataset2['zoo_id'] = 'zoo2'
dataset3['zoo_id'] = 'zoo3'

# %%
dataset = pd.concat([dataset1, dataset2, dataset3], axis = 0)
dataset.shape
# Out:
# (214, 19)

# %%
dataset.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    class_type zoo_id
# 0           1   zoo1
# 1           1   zoo1
# ...

# %%
# Looking for null values
dataset.isnull().sum()
# Out:
# animal_name    0
# hair           0
# feathers       0
# eggs           0
# milk           0
# airborne       0
# aquatic        0
# predator       0
# toothed        0
# backbone       0
# breathes       0
# venomous       0
# fins           0
# legs           0
# tail           0
# domestic       0
# catsize        0
# class_type     0
# zoo_id         0
# dtype: int64

# %%
# Looking for duplicate values
duplicates = dataset.duplicated()
duplicates[duplicates > 1]
# Out:
# Series([], dtype: bool)

# %%
# Checking if animal names are unique
duplicate_names = dataset.animal_name.value_counts()
duplicate_names[duplicate_names > 1]
# Out:
# frog    2
# Name: animal_name, dtype: int64

# %%
# Selecting to see the frog data
dataset.loc[dataset['animal_name'] == 'frog']
# Out:
#    animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 25        frog     0         0     1     0         0        1         1
# 26        frog     0         0     1     0         0        1         1
#
#     toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 25        1         1         1         0     0     4     0         0
# 26        1         1         1         1     0     4     0         0
#
#     catsize  class_type zoo_id
# 25        0           5   zoo1
# 26        0           5   zoo1

# %%
# Found that one frog is venomous, while other is not, so changing the name of the venomous frog to venomous_frog from frog
dataset['animal_name'][(dataset.venomous == 1) & (dataset.animal_name == 'frog')] = "venoumous_frog"
# Out:
# C:\Users\Dharshini\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(dataset.animal_name.unique())
# Out:
# 214

# %%
# Checking datatypes (data validation)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 69
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animal_name  214 non-null    object
#  1   hair         214 non-null    int64
#  2   feathers     214 non-null    int64
#  3   eggs         214 non-null    int64
#  4   milk         214 non-null    int64
#  5   airborne     214 non-null    int64
#  6   aquatic      214 non-null    int64
#  7   predator     214 non-null    int64
#  8   toothed      214 non-null    int64
#  9   backbone     214 non-null    int64
#  10  breathes     214 non-null    int64
#  11  venomous     214 non-null    int64
#  12  fins         214 non-null    int64
#  13  legs         214 non-null    int64
#  14  tail         214 non-null    int64
#  15  domestic     214 non-null    int64
#  16  catsize      214 non-null    int64
#  17  class_type   214 non-null    int64
#  18  zoo_id       214 non-null    object
# ...

# %%
# Number of animals in each class
print("\nNumber of animals in each class")
print(dataset['class_type'].value_counts().sort_index())
# Out:
# Number of animals in each class
# 1    60
# 2    40
# 3    25
# 4    28
# 5    16
# 6    25
# 7    20
# Name: class_type, dtype: int64

# %%
# Data Visualization
# Distribution of Age in a Count Plot
classes = ["Mammal", "Bird", "Reptile", "Fish", "Amphibian", "Insect", "Invertebrate"]
ax = sns.countplot(x='class_type',data=dataset, palette=("Set1"))
ax.set_xticklabels(classes)
plt.xlabel('Class Type')
plt.ylabel('Count of animals in class')
plt.title('Distribution of Animals')
plt.show()

# %%
classes = ["Mammal", "Bird", "Reptile", "Fish", "Amphibian", "Insect", "Invertebrate"]
ax = sns.countplot(x='class_type', hue='zoo_id', data=dataset, palette=("Set2"))
ax.set_xticklabels(classes, rotation = 45)
# Out:
# [Text(0, 0, 'Mammal'),
#  Text(0, 0, 'Bird'),
#  Text(0, 0, 'Reptile'),
#  Text(0, 0, 'Fish'),
#  Text(0, 0, 'Amphibian'),
#  Text(0, 0, 'Insect'),
#  Text(0, 0, 'Invertebrate')]

# %%
features = ['hair', 'feathers', 'eggs', 'milk', 'airborne', 'aquatic', 'predator', 'toothed', 'backbone', 'breathes', 'venomous', 'fins', 'tail', 'legs', 'domestic', 'catsize']
values = [False, True]

f_no = 0
fig, ax = plt.subplots(4, 4, figsize = (20, 15))
for x_num in range(0, 4):
    for y_num in range(0,4):
        #print(x_num, y_num, features[f_no])
        sns.countplot(x=dataset[features[f_no]], ax = ax[x_num, y_num], palette=("Set2"))
        if(features[f_no]=='legs'):
            ax[x_num, y_num].set_xticklabels([0, 2, 4, 5, 6, 8])
        else:
            ax[x_num, y_num].set_xticklabels(values)
        f_no += 1
plt.show()

# %%
features = ['hair', 'feathers', 'eggs', 'milk', 'airborne', 'aquatic', 'predator', 'toothed', 'backbone', 'breathes', 'venomous', 'fins', 'tail', 'legs', 'domestic', 'catsize']
values = [False, True]

f_no = 0
fig, ax = plt.subplots(4, 4, figsize = (20, 15))
for x_num in range(0, 4):
    for y_num in range(0,4):
        #print(x_num, y_num, features[f_no])
        sns.countplot(x=dataset[features[f_no]], hue=dataset['class_type'], ax = ax[x_num, y_num], palette=("Set1"))
        if(features[f_no]=='legs'):
            ax[x_num, y_num].set_xticklabels([0, 2, 4, 5, 6, 8])
        else:
            ax[x_num, y_num].set_xticklabels(values)
        ax[x_num, y_num].get_legend().remove()
        f_no += 1
fig.legend(labels = classes, loc = 'upper right')
plt.show()

# %%
plt.subplots(figsize=(20,15))
ax = plt.axes()
ax.set_title("Correlation Heatmap")
corr = dataset.corr()
sns.heatmap(corr,  cmap="YlGnBu", annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
corr_filt = corr[corr != 1][abs(corr)> 0.7].dropna(how='all', axis=1).dropna(how='all', axis=0)
print(corr_filt)
# Out:
#                 hair      eggs      milk  backbone      tail  class_type
# hair             NaN -0.833471  0.867128       NaN       NaN         NaN
# eggs       -0.833471       NaN -0.965500       NaN       NaN         NaN
# milk        0.867128 -0.965500       NaN       NaN       NaN         NaN
# backbone         NaN       NaN       NaN       NaN  0.723502   -0.800755
# tail             NaN       NaN       NaN  0.723502       NaN         NaN
# class_type       NaN       NaN       NaN -0.800755       NaN         NaN

# %%
dataset[dataset.columns[1:]].corr()['class_type'][:]
# Out:
# hair         -0.502266
# feathers     -0.293420
# eggs          0.653506
# milk         -0.685874
# airborne      0.017806
# aquatic       0.234282
# predator     -0.098951
# toothed      -0.434542
# backbone     -0.800755
# breathes     -0.340721
# venomous      0.309159
# fins          0.030783
# legs          0.190931
# tail         -0.687584
# domestic     -0.163233
# catsize      -0.421507
# class_type    1.000000
# Name: class_type, dtype: float64

# %%
X = dataset.iloc[:, 1:17].values
y = dataset.iloc[:, 17].values

# %%
from sklearn.feature_selection import chi2
chi_scores = chi2(X,y)
print(chi_scores)
# Out:
# (array([116.58090909, 174.        ,  56.95311547, 154.        ,
#        109.52559748,  67.92860759,   9.70531667,  73.79885547,
#         45.        ,  29.58069805,  24.67481366, 141.19333333,
#        191.58200751,  48.24814943,   7.86865646,  26.69789489]), array([8.50825175e-23, 6.37340477e-35, 1.86728754e-10, 1.10294912e-30,
#        2.56222620e-21, 1.08658864e-12, 1.37622948e-01, 6.78140542e-14,
#        4.68021263e-08, 4.72198739e-05, 3.92174789e-04, 5.61174013e-28,
#        1.17268670e-38, 1.05410800e-08, 2.47884701e-01, 1.64945360e-04]))

# %%
p_values = pd.Series(chi_scores[1])

#Null Hypothesis: Two variables are independent
#Alternate Hypothesis: Two variables are not independent
alpha = 0.05

ind = 0
for p in p_values:
    if p <= alpha:
        print(features[ind],'variable is dependent of the target variable class_type (reject H0)')
    else:
        print(features[ind],'variable is independent of the target varible class_type (fail to reject H0)')
    ind += 1
    
p_values.sort_values(ascending = False , inplace = True)
print(p_values.plot.bar())
# Out:
# hair variable is dependent of the target variable class_type (reject H0)
# feathers variable is dependent of the target variable class_type (reject H0)
# eggs variable is dependent of the target variable class_type (reject H0)
# milk variable is dependent of the target variable class_type (reject H0)
# airborne variable is dependent of the target variable class_type (reject H0)
# aquatic variable is dependent of the target variable class_type (reject H0)
# predator variable is independent of the target varible class_type (fail to reject H0)
# toothed variable is dependent of the target variable class_type (reject H0)
# backbone variable is dependent of the target variable class_type (reject H0)
# breathes variable is dependent of the target variable class_type (reject H0)
# venomous variable is dependent of the target variable class_type (reject H0)
# fins variable is dependent of the target variable class_type (reject H0)
# ...

# %%
X = dataset.loc[:, ['hair','feathers','eggs','milk','airborne','aquatic','toothed','backbone','breathes','venomous','fins','legs','tail','catsize']].values
y = dataset.iloc[:, 17].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
def get_confusion_matrix(classifier, X_test, y_test):
    # Plot matrix
    from sklearn.metrics import plot_confusion_matrix
    disp = plot_confusion_matrix(classifier, X_test, y_test, display_labels = classes, cmap='Blues')
    disp.ax_.set_title("Confusion Matrix")
    plt.show()

# %%
def get_classification_report(classifier):
    from yellowbrick.classifier import classification_report
    print(classification_report(classifier, X_train, y_train, X_test, y_test, cmap='Blues', support=True))

# %%
def get_class_prediction_error(classifier):
    from yellowbrick.classifier import class_prediction_error
    print(class_prediction_error(classifier, X_train, y_train, X_test, y_test, cmap='Blues'))

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
get_confusion_matrix(classifier, X_test, y_test)
get_classification_report(classifier)
get_class_prediction_error(classifier)
from sklearn.metrics import accuracy_score
print("Overall Accuracy: ",accuracy_score(y_test, y_pred))
# Out:
# ClassificationReport(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC47DC3288>,
#                      classes=None,
#                      cmap=<matplotlib.colors.ListedColormap object at 0x000001EC48446E48>,
#                      encoder=None,
#                      estimator=GaussianNB(priors=None, var_smoothing=1e-09),
#                      force_model=False, is_fitted='auto', support=True)
# ClassPredictionError(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC484B5E08>,
#                      classes=None, encoder=None,
#                      estimator=GaussianNB(priors=None, var_smoothing=1e-09),
#                      force_model=False, is_fitted='auto')
# Overall Accuracy:  0.9692307692307692

# %%
from sklearn.ensemble import GradientBoostingClassifier
classifier = GradientBoostingClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
get_confusion_matrix(classifier, X_test, y_test)
get_classification_report(classifier)
get_class_prediction_error(classifier)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
print("Overall Accuracy: ",accuracy_score(y_test, y_pred))
# Out:
# ClassificationReport(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC4973AEC8>,
#                      classes=None,
#                      cmap=<matplotlib.colors.ListedColormap object at 0x000001EC49637788>,
#                      encoder=None,
#                      estimator=GradientBoostingClassifier(ccp_alpha=0.0,
#                                                           criterion='friedman_mse',
#                                                           init=None,
#                                                           learning_rate=0.1,
#                                                           loss='deviance',
#                                                           max_depth=3,
#                                                           max_features=None,
#                                                           max_leaf_nodes=None,
#                                                           min_impurity_decrease=0.0,
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
get_confusion_matrix(classifier, X_test, y_test)
get_classification_report(classifier)
get_class_prediction_error(classifier)
from sklearn.metrics import accuracy_score
print("Overall Accuracy: ",accuracy_score(y_test, y_pred))
# Out:
# ClassificationReport(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC47D94E48>,
#                      classes=None,
#                      cmap=<matplotlib.colors.ListedColormap object at 0x000001EC47B4DC08>,
#                      encoder=None,
#                      estimator=RandomForestClassifier(bootstrap=True,
#                                                       ccp_alpha=0.0,
#                                                       class_weight=None,
#                                                       criterion='gini',
#                                                       max_depth=None,
#                                                       max_features='auto',
#                                                       max_leaf_nodes=None,
#                                                       max_samples=None,
#                                                       min_impurity_decrease=0.0,
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(class_weight='balanced')
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
get_confusion_matrix(classifier, X_test, y_test)
get_classification_report(classifier)
get_class_prediction_error(classifier)
from sklearn.metrics import accuracy_score
print("Overall Accuracy: ",accuracy_score(y_test, y_pred))
# Out:
# ClassificationReport(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC4980D988>,
#                      classes=None,
#                      cmap=<matplotlib.colors.ListedColormap object at 0x000001EC4980D908>,
#                      encoder=None,
#                      estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                       class_weight='balanced',
#                                                       criterion='gini',
#                                                       max_depth=None,
#                                                       max_features=None,
#                                                       max_leaf_nodes=None,
#                                                       min_impurity_decrease=0.0,
#                                                       min_impurity_split=None,
#                                                       min_samples_leaf=1,
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
get_confusion_matrix(classifier, X_test, y_test)
get_classification_report(classifier)
get_class_prediction_error(classifier)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# ClassificationReport(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC499D2208>,
#                      classes=None,
#                      cmap=<matplotlib.colors.ListedColormap object at 0x000001EC499BB148>,
#                      encoder=None,
#                      estimator=KNeighborsClassifier(algorithm='auto',
#                                                     leaf_size=30,
#                                                     metric='minkowski',
#                                                     metric_params=None,
#                                                     n_jobs=None, n_neighbors=5,
#                                                     p=2, weights='uniform'),
#                      force_model=False, is_fitted='auto', support=True)
# ClassPredictionError(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC499C9A88>,
#                      classes=None, encoder=None,
# ...
